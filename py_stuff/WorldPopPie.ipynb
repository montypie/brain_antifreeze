# %%
import pandas as pd
data_overview = pd.read_csv("inputs/worldpop2020.csv")
data_overview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Pop         6 non-null      int64
#  2   GrowthRate  6 non-null      float64
#  3   WorldPop    6 non-null      float64
#  4   PopDensity  6 non-null      float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

def make_a_pie(year):
    """ Pie charts of worldpop """

    data_file = f"inputs/worldpop{year}.csv"
    pie_file = f"outputs/worldpie{year}.png"
    csv_reader = csv.reader(open(data_file))

    labels,numbers,sizes = [],[],[]
    firstline = True

    for line in csv_reader:
        if firstline:
            firstline = False
            continue
        labels.append(line[0])
        numbers.append(int(line[1]))
        sizes.append(float(line[3]))

    d_numbers = []
    for num in numbers:
        d_numbers.append('{}'.format(round(float(num/1000000), 1)))

    colors = ['#ffb35f','#d95655','#a19fff', '#a0c0a0', '#cdff9f', '#5fabff']

    plt.figure(figsize=plt.figaspect(1))

    plt.pie(numbers, labels=d_numbers, colors=colors, startangle=65)
    plt.title(f'World population in {year}, mil')
    plt.legend(labels, loc='upper left')
    plt.savefig(pie_file)
    plt.show()

# %%
year = ['2020','2025']
for y in year:
    make_a_pie(y)
